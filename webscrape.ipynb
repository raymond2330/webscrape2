# %% [markdown]
# # Scraping Data from a Real Website + Pandas

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.google.com.ph/travel/hotels/entity/CgoImZTP7qnD_KojEAE/reviews?utm_campaign=sharing&utm_medium=link&utm_source=htls&ts=CAEaBAoCGgAqBAoAGgA'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
import requests
from bs4 import BeautifulSoup

# Set the URL
url = 'https://www.google.com.ph/travel/hotels/entity/CgoImZTP7qnD_KojEAE/reviews?utm_campaign=sharing&utm_medium=link&utm_source=htls&ts=CAEaBAoCGgAqBAoAGgA'

# Set headers to make the request look like it comes from a browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}

# Send the request
response = requests.get(url, headers=headers)

# Check the response status
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Print the parsed HTML to check its structure
    print(soup.prettify())
    
    # Try to find the specific div
    element = soup.find('div', class_='Svr5cf bKhjM')
    if element:
        print(element)
    else:
        print("Element not found")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="fil">
#  <head>
#   <base href="https://www.google.com.ph/"/>
#   <link href="//www.gstatic.com" ref="preconnect"/>
#   <meta content="strict-origin-when-cross-origin" name="referrer"/>
#   <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="light dark" name="color-scheme"/>
#   <meta content="vzI4y-3iMecKTIHcKK5ZK6Ox4-K5SAJWV5tqgCxry20" name="google-site-verification"/>
#   <meta content="sxp7zFOFUzk09RdlFhuH2SoCn5nOkXgomiLeLIQ48p0" name="google-site-verification"/>
#   <meta content="uceYfkdbu7tdKGywiwSr1p0cIbqdYOwMDkNq5jVFwMA" name="google-site-verification"/>
#   <meta content="J5sh_MiITOLlJ0-QvzozVJ_zG-LKEfWecDaWrgIO4Yw" name="google-site-verification"/>
#   <meta content="O5G3B9VUIil1GEVlPw3BfdeYn_kZeNd_6rsDolHah5w" name="google-site-verification"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="fil" prefix="og: http://ogp.me/ns# ">
#  <head>
#   <base href="https://www.google.com.ph/"/>
#   <link href="//www.gstatic.com" ref="preconnect"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="true" name="mod"/>
#   <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="Paglalakbay" name="application-name"/>
#   <meta content="Paglalakbay" name="apple-mobile-web-app-title"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <link crossorigin="use-credentials" href="_/TravelFrontendUi/manifest.json" rel="manifest"/>
#   <link href="/travel/?dest_src=homescreen_app&amp;lfhs=2" rel="home"/>
# ...

# %%
print(soup.find_all('div', class_='Svr5cf.bKhjM'))
# Out:
# []

# %%
print("Using CSS selector:", soup.select_one('div[jsname="Pa5DKe"]'))
# Out:
# Using CSS selector: None

# %%
print(soup.find(jsname='Pa5DKe'))
# Out:
# None

# %%
print(soup.find_all('div', jsname='Pa5DKe'))
# Out:
# []

# %%
soup.find_all('table')
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
soup.find('table', class_ = 'wikitable sortable')
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD millions)
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]

print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth', 'Employees', 'Headquarters']

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank                      Name                    Industry  \
# 0     1                   Walmart                      Retail
# 1     2                    Amazon  Retail and cloud computing
# 2     3                ExxonMobil          Petroleum industry
# 3     4                     Apple        Electronics industry
# 4     5        UnitedHealth Group                  Healthcare
# ..  ...                       ...                         ...
# 95   96                  Best Buy                      Retail
# 96   97      Bristol-Myers Squibb     Pharmaceutical industry
# 97   98           United Airlines                     Airline
# 98   99  Thermo Fisher Scientific      Laboratory instruments
# 99  100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df.to_csv(r'C:\Users\pr_re\OneDrive\Desktop\webscrape2\output.csv', index = False)
